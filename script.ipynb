# %% [markdown]
# # Importando as bibliotecas

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Média

# %%
#falta

# %% [markdown]
# Mediana

# %%
#falta

# %% [markdown]
# Moda

# %%
#falta

# %% [markdown]
# Max

# %%
#falta

# %% [markdown]
# Min

# %%
#falta

# %% [markdown]
# Desvio

# %%
#falta
