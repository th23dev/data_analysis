# %% [markdown]
# # Importando as bibliotecas

# %%
import pandas as pd
import matplotlib

# %% [markdown]
# Média

# %% [markdown]
# Mediana

# %% [markdown]
# Moda

# %% [markdown]
# Max

# %% [markdown]
# Min

# %% [markdown]
# Desvio
