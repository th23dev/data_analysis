# %% [markdown]
# *Importando as bibliotecas*

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Data Base

# %%
db = pd.read_csv('outputs/para/tables/comparacao_filtros_para.csv')
db.head()
# Out:
#     ano  residentes_pa_total_notificacao  residentes_pa_sem_descartados  \
# 0  2022                             6126                           6126
# 1  2023                             5878                           5878
# 2  2024                            21069                          21069
# 3  2025                            16943                          16943
# 4  2026                             7536                           7536
#
#    residentes_pa_confirmados_dengue  residentes_pa_descartados  \
# 0                              4780                          0
# 1                              4559                          0
# 2                             18252                          0
# 3                             15091                          0
# 4                              5195                          0
#
#    residentes_pa_inconclusivos  notificados_no_pa_total  \
# 0                         1332                     5912
# ...

# %% [markdown]
# Média

# %%
#falta
print(f"A média dos preços é: ${db['Price'].mean().round(2)}")
# Out:
# A média dos preços é: $506.55

# %% [markdown]
# Mediana

# %%
#falta
print(f"A mediana dos preços é: ${db['Price'].median()}")
# Out:
# A mediana dos preços é: $497.5

# %% [markdown]
# Moda

# %%
#falta
moda_size = db['Size'].mode()[0]
print(f"A moda dos tamanhos é: {moda_size}")
# Out:
# A moda dos tamanhos é:8x10 in

# %% [markdown]
# Max

# %%
#falta
print(f"O preço máximo é: ${db['Price'].max()}")
# Out:
# O preço máximo é: $999

# %% [markdown]
# Min

# %%
#falta
print(f"O preço mínimo é: ${db['Price'].min()}")
# Out:
# O preço mínimo é: $1

# %% [markdown]
# Desvio

# %%
#falta
print(f"O desvio padrão é: ${db['Price'].std().round(2)}")
# Out:
# O desvio padrão é: $283.77
